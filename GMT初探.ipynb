# %%
import gmt
gmt.test()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-0a358092a954> in <module>()
# ----> 1 import gmt
#       2 gmt.test()
#
# /home/hadoop/anaconda3/lib/python3.5/site-packages/gmt/__init__.py in <module>()
#      13 # Import modules to make the high-level GMT Python API
#      14 from .session_management import begin as _begin, end as _end
# ---> 15 from .figure import Figure
#      16 from .modules import info, grdinfo, which
#      17 from . import datasets
#
# /home/hadoop/anaconda3/lib/python3.5/site-packages/gmt/figure.py in <module>()
#      12
#      13 from .clib import Session
# ---> 14 from .base_plotting import BasePlotting
#      15 from .exceptions import GMTError, GMTInvalidInput
#      16 from .helpers import (
#
# /home/hadoop/anaconda3/lib/python3.5/site-packages/gmt/base_plotting.py in <module>()
#       5 from .clib import Session
# ...
